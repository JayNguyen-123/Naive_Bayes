# %% [markdown]
# <a href="https://colab.research.google.com/github/JayNguyen-123/Naive_Bayes/blob/main/Titanic_Survivor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(['PassengerId','Name','Parch','Ticket','Cabin','Embarked'], axis='columns', inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp     Fare
# 0         0       3    male  22.0      1   7.2500
# 1         1       1  female  38.0      1  71.2833
# 2         1       3  female  26.0      0   7.9250
# 3         1       1  female  35.0      1  53.1000
# 4         0       3    male  35.0      0   8.0500

# %%
target = df.Survived
inputs = df.drop('Survived', axis='columns')

# %%
dummies = pd.get_dummies(inputs.Sex)
dummies.head(3)
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2    True  False

# %%
inputs = pd.concat([inputs,dummies], axis='columns')
inputs.head(3)
# Out:
#    Pclass     Sex   Age  SibSp     Fare  female   male
# 0       3    male  22.0      1   7.2500   False   True
# 1       1  female  38.0      1  71.2833    True  False
# 2       3  female  26.0      0   7.9250    True  False

# %%
inputs.drop('Sex',axis='columns', inplace=True)
inputs.head(3)
# Out:
#    Pclass   Age  SibSp     Fare  female   male
# 0       3  22.0      1   7.2500   False   True
# 1       1  38.0      1  71.2833    True  False
# 2       3  26.0      0   7.9250    True  False

# %%
inputs.columns[inputs.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
inputs.Age[:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
inputs.Age = inputs.Age.fillna(inputs.Age.mean())
inputs.head(10)
# Out:
#    Pclass        Age  SibSp     Fare  female   male
# 0       3  22.000000      1   7.2500   False   True
# 1       1  38.000000      1  71.2833    True  False
# 2       3  26.000000      0   7.9250    True  False
# 3       1  35.000000      1  53.1000    True  False
# 4       3  35.000000      0   8.0500   False   True
# 5       3  29.699118      0   8.4583   False   True
# 6       1  54.000000      0  51.8625   False   True
# 7       3   2.000000      3  21.0750   False   True
# 8       3  27.000000      0  11.1333    True  False
# 9       2  14.000000      1  30.0708    True  False

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test, y_test)
# Out:
# 0.8044692737430168

# %%
y_test[:10]
# Out:
# 239    0
# 149    0
# 572    1
# 600    1
# 838    1
# 378    0
# 164    0
# 676    0
# 471    0
# 736    0
# Name: Survived, dtype: int64

# %%
model.predict(X_test[:10])
# Out:
# array([0, 0, 0, 1, 0, 0, 0, 0, 0, 1])

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[9.65474884e-01, 3.45251161e-02],
#        [9.64603252e-01, 3.53967476e-02],
#        [8.69565236e-01, 1.30434764e-01],
#        [1.33876909e-01, 8.66123091e-01],
#        [9.72673438e-01, 2.73265617e-02],
#        [9.81221109e-01, 1.87788914e-02],
#        [9.99995102e-01, 4.89845602e-06],
#        [9.83062807e-01, 1.69371930e-02],
#        [9.84309706e-01, 1.56902942e-02],
#        [6.28156726e-02, 9.37184327e-01]])
